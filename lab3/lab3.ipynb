# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Data2.csv', on_bad_lines='skip', encoding='cp1252', delimiter=';')
df
# Out:
#               Country Name                      Region GDP per capita  \
# 0              Afghanistan                  South Asia    561,7787463
# 1                  Albania       Europe & Central Asia     4124,98239
# 2                  Algeria  Middle East & North Africa    3916,881571
# 3           American Samoa         East Asia & Pacific    11834,74523
# 4                  Andorra       Europe & Central Asia    36988,62203
# ..                     ...                         ...            ...
# 212  Virgin Islands (U.S.)   Latin America & Caribbean            NaN
# 213     West Bank and Gaza  Middle East & North Africa    2943,404534
# 214            Yemen, Rep.  Middle East & North Africa     990,334774
# 215                 Zambia          Sub-Saharan Africa    1269,573537
# 216               Zimbabwe          Sub-Saharan Africa    1029,076649
#
#      Populatiion CO2 emission     Area
# 0     34656032.0     9809,225   652860
# 1      2876101.0     5716,853    28750
# 2     40606052.0   145400,217  2381740
# 3        55599.0          NaN      200
# 4        77281.0      462,042      470
# ..           ...          ...      ...
# 212     102951.0          NaN      350
# 213    4551566.0          NaN     6020
# 214   27584213.0     22698,73   527970
# 215   16591390.0     4503,076   752610
# 216   16150362.0    12020,426   390760
#
# [217 rows x 6 columns]

# %%
df.dtypes
# Out:
# Country Name       object
# Region             object
# GDP per capita     object
# Populatiion       float64
# CO2 emission       object
# Area               object
# dtype: object

# %%
df.columns = ['country_name', 'region', 'gdp_per_capita', 'population', 'co2_emission', 'area']
df
# Out:
#               country_name                      region gdp_per_capita  \
# 0              Afghanistan                  South Asia    561,7787463
# 1                  Albania       Europe & Central Asia     4124,98239
# 2                  Algeria  Middle East & North Africa    3916,881571
# 3           American Samoa         East Asia & Pacific    11834,74523
# 4                  Andorra       Europe & Central Asia    36988,62203
# ..                     ...                         ...            ...
# 212  Virgin Islands (U.S.)   Latin America & Caribbean            NaN
# 213     West Bank and Gaza  Middle East & North Africa    2943,404534
# 214            Yemen, Rep.  Middle East & North Africa     990,334774
# 215                 Zambia          Sub-Saharan Africa    1269,573537
# 216               Zimbabwe          Sub-Saharan Africa    1029,076649
#
#      population co2_emission     area
# 0    34656032.0     9809,225   652860
# 1     2876101.0     5716,853    28750
# 2    40606052.0   145400,217  2381740
# 3       55599.0          NaN      200
# 4       77281.0      462,042      470
# ..          ...          ...      ...
# 212    102951.0          NaN      350
# 213   4551566.0          NaN     6020
# 214  27584213.0     22698,73   527970
# 215  16591390.0     4503,076   752610
# 216  16150362.0    12020,426   390760
#
# [217 rows x 6 columns]

# %%
df.set_index('country_name', inplace=True)
df
# Out:
#                                            region gdp_per_capita  population  \
# country_name
# Afghanistan                            South Asia    561,7787463  34656032.0
# Albania                     Europe & Central Asia     4124,98239   2876101.0
# Algeria                Middle East & North Africa    3916,881571  40606052.0
# American Samoa                East Asia & Pacific    11834,74523     55599.0
# Andorra                     Europe & Central Asia    36988,62203     77281.0
# ...                                           ...            ...         ...
# Virgin Islands (U.S.)   Latin America & Caribbean            NaN    102951.0
# West Bank and Gaza     Middle East & North Africa    2943,404534   4551566.0
# Yemen, Rep.            Middle East & North Africa     990,334774  27584213.0
# Zambia                         Sub-Saharan Africa    1269,573537  16591390.0
# Zimbabwe                       Sub-Saharan Africa    1029,076649  16150362.0
#
#                       co2_emission     area
# country_name
# Afghanistan               9809,225   652860
# Albania                   5716,853    28750
# Algeria                 145400,217  2381740
# American Samoa                 NaN      200
# Andorra                    462,042      470
# ...                            ...      ...
# Virgin Islands (U.S.)          NaN      350
# West Bank and Gaza             NaN     6020
# Yemen, Rep.               22698,73   527970
# Zambia                    4503,076   752610
# Zimbabwe                 12020,426   390760
#
# [217 rows x 5 columns]

# %%
df.gdp_per_capita = df.gdp_per_capita.astype(str).str.replace(',', '.').astype(float)
df.co2_emission = df.co2_emission.astype(str).str.replace(',', '.').astype(float)
df.area = df.area.astype(str).str.replace(',', '.').astype(float)
df
# Out:
#                                            region  gdp_per_capita  population  \
# country_name
# Afghanistan                            South Asia      561.778746  34656032.0
# Albania                     Europe & Central Asia     4124.982390   2876101.0
# Algeria                Middle East & North Africa     3916.881571  40606052.0
# American Samoa                East Asia & Pacific    11834.745230     55599.0
# Andorra                     Europe & Central Asia    36988.622030     77281.0
# ...                                           ...             ...         ...
# Virgin Islands (U.S.)   Latin America & Caribbean             NaN    102951.0
# West Bank and Gaza     Middle East & North Africa     2943.404534   4551566.0
# Yemen, Rep.            Middle East & North Africa      990.334774  27584213.0
# Zambia                         Sub-Saharan Africa     1269.573537  16591390.0
# Zimbabwe                       Sub-Saharan Africa     1029.076649  16150362.0
#
#                        co2_emission       area
# country_name
# Afghanistan                9809.225   652860.0
# Albania                    5716.853    28750.0
# Algeria                  145400.217  2381740.0
# American Samoa                  NaN      200.0
# Andorra                     462.042      470.0
# ...                             ...        ...
# Virgin Islands (U.S.)           NaN      350.0
# West Bank and Gaza              NaN     6020.0
# Yemen, Rep.               22698.730   527970.0
# Zambia                     4503.076   752610.0
# Zimbabwe                  12020.426   390760.0
#
# [217 rows x 5 columns]

# %%
df.dtypes
# Out:
# region             object
# gdp_per_capita    float64
# population        float64
# co2_emission      float64
# area              float64
# dtype: object

# %%
df.gdp_per_capita = df.gdp_per_capita.abs()
df.area = df.area.abs()
df
# Out:
#                                            region  gdp_per_capita  population  \
# country_name
# Afghanistan                            South Asia      561.778746  34656032.0
# Albania                     Europe & Central Asia     4124.982390   2876101.0
# Algeria                Middle East & North Africa     3916.881571  40606052.0
# American Samoa                East Asia & Pacific    11834.745230     55599.0
# Andorra                     Europe & Central Asia    36988.622030     77281.0
# ...                                           ...             ...         ...
# Virgin Islands (U.S.)   Latin America & Caribbean             NaN    102951.0
# West Bank and Gaza     Middle East & North Africa     2943.404534   4551566.0
# Yemen, Rep.            Middle East & North Africa      990.334774  27584213.0
# Zambia                         Sub-Saharan Africa     1269.573537  16591390.0
# Zimbabwe                       Sub-Saharan Africa     1029.076649  16150362.0
#
#                        co2_emission       area
# country_name
# Afghanistan                9809.225   652860.0
# Albania                    5716.853    28750.0
# Algeria                  145400.217  2381740.0
# American Samoa                  NaN      200.0
# Andorra                     462.042      470.0
# ...                             ...        ...
# Virgin Islands (U.S.)           NaN      350.0
# West Bank and Gaza              NaN     6020.0
# Yemen, Rep.               22698.730   527970.0
# Zambia                     4503.076   752610.0
# Zimbabwe                  12020.426   390760.0
#
# [217 rows x 5 columns]

# %%
df.isna().any()
# Out:
# region            False
# gdp_per_capita     True
# population         True
# co2_emission       True
# area              False
# dtype: bool

# %%
df.gdp_per_capita.fillna(df.gdp_per_capita.mean(), inplace=True)
df.population.fillna(df.population.mean(), inplace=True)
df.co2_emission.fillna(df.co2_emission.mean(), inplace=True)
df
# Out:
#                                            region  gdp_per_capita  population  \
# country_name
# Afghanistan                            South Asia      561.778746  34656032.0
# Albania                     Europe & Central Asia     4124.982390   2876101.0
# Algeria                Middle East & North Africa     3916.881571  40606052.0
# American Samoa                East Asia & Pacific    11834.745230     55599.0
# Andorra                     Europe & Central Asia    36988.622030     77281.0
# ...                                           ...             ...         ...
# Virgin Islands (U.S.)   Latin America & Caribbean    13445.593416    102951.0
# West Bank and Gaza     Middle East & North Africa     2943.404534   4551566.0
# Yemen, Rep.            Middle East & North Africa      990.334774  27584213.0
# Zambia                         Sub-Saharan Africa     1269.573537  16591390.0
# Zimbabwe                       Sub-Saharan Africa     1029.076649  16150362.0
#
#                         co2_emission       area
# country_name
# Afghanistan              9809.225000   652860.0
# Albania                  5716.853000    28750.0
# Algeria                145400.217000  2381740.0
# American Samoa         165114.116337      200.0
# Andorra                   462.042000      470.0
# ...                              ...        ...
# Virgin Islands (U.S.)  165114.116337      350.0
# West Bank and Gaza     165114.116337     6020.0
# Yemen, Rep.             22698.730000   527970.0
# Zambia                   4503.076000   752610.0
# Zimbabwe                12020.426000   390760.0
#
# [217 rows x 5 columns]

# %%
df.isna().any()
# Out:
# region            False
# gdp_per_capita    False
# population        False
# co2_emission      False
# area              False
# dtype: bool

# %%
df.population = df.population.astype(int)
df
# Out:
#                                            region  gdp_per_capita  population  \
# country_name
# Afghanistan                            South Asia      561.778746    34656032
# Albania                     Europe & Central Asia     4124.982390     2876101
# Algeria                Middle East & North Africa     3916.881571    40606052
# American Samoa                East Asia & Pacific    11834.745230       55599
# Andorra                     Europe & Central Asia    36988.622030       77281
# ...                                           ...             ...         ...
# Virgin Islands (U.S.)   Latin America & Caribbean    13445.593416      102951
# West Bank and Gaza     Middle East & North Africa     2943.404534     4551566
# Yemen, Rep.            Middle East & North Africa      990.334774    27584213
# Zambia                         Sub-Saharan Africa     1269.573537    16591390
# Zimbabwe                       Sub-Saharan Africa     1029.076649    16150362
#
#                         co2_emission       area
# country_name
# Afghanistan              9809.225000   652860.0
# Albania                  5716.853000    28750.0
# Algeria                145400.217000  2381740.0
# American Samoa         165114.116337      200.0
# Andorra                   462.042000      470.0
# ...                              ...        ...
# Virgin Islands (U.S.)  165114.116337      350.0
# West Bank and Gaza     165114.116337     6020.0
# Yemen, Rep.             22698.730000   527970.0
# Zambia                   4503.076000   752610.0
# Zimbabwe                12020.426000   390760.0
#
# [217 rows x 5 columns]

# %%
df.hist(figsize=(20, 12));

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 10))
axes[0, 0].boxplot(df.gdp_per_capita)
axes[0, 0].set_title('GDP per capita')
axes[0, 1].boxplot(df.population)
axes[0, 1].set_title('Population')
axes[1, 0].boxplot(df.co2_emission)
axes[1, 0].set_title('CO2 emission')
axes[1, 1].boxplot(df.area)
axes[1, 1].set_title('Area');

# %%
df['density'] = df.population / df.area
df
# Out:
#                                            region  gdp_per_capita  population  \
# country_name
# Afghanistan                            South Asia      561.778746    34656032
# Albania                     Europe & Central Asia     4124.982390     2876101
# Algeria                Middle East & North Africa     3916.881571    40606052
# American Samoa                East Asia & Pacific    11834.745230       55599
# Andorra                     Europe & Central Asia    36988.622030       77281
# ...                                           ...             ...         ...
# Virgin Islands (U.S.)   Latin America & Caribbean    13445.593416      102951
# West Bank and Gaza     Middle East & North Africa     2943.404534     4551566
# Yemen, Rep.            Middle East & North Africa      990.334774    27584213
# Zambia                         Sub-Saharan Africa     1269.573537    16591390
# Zimbabwe                       Sub-Saharan Africa     1029.076649    16150362
#
#                         co2_emission       area     density
# country_name
# Afghanistan              9809.225000   652860.0   53.083405
# Albania                  5716.853000    28750.0  100.038296
# Algeria                145400.217000  2381740.0   17.048902
# American Samoa         165114.116337      200.0  277.995000
# Andorra                   462.042000      470.0  164.427660
# ...                              ...        ...         ...
# Virgin Islands (U.S.)  165114.116337      350.0  294.145714
# West Bank and Gaza     165114.116337     6020.0  756.074086
# Yemen, Rep.             22698.730000   527970.0   52.245796
# Zambia                   4503.076000   752610.0   22.045136
# Zimbabwe                12020.426000   390760.0   41.330643
#
# [217 rows x 6 columns]

# %%
df.loc[[df.gdp_per_capita.idxmax()]]
# Out:
#                              region  gdp_per_capita  population  co2_emission  \
# country_name
# Luxembourg    Europe & Central Asia     100738.6842      582972      9658.878
#
#                 area     density
# country_name
# Luxembourg    2590.0  225.085714

# %%
df.loc[[df.area.idxmin()]]
# Out:
#                              region  gdp_per_capita  population  \
# country_name
# Monaco        Europe & Central Asia    13445.593416       38499
#
#                co2_emission  area  density
# country_name
# Monaco        165114.116337   2.0  19249.5

# %%
group = df.groupby('region').area.mean()
group.loc[[group.idxmax()]]
# Out:
# region
# North America    6605410.0
# Name: area, dtype: float64

# %%
df.loc[[df.density.idxmax()]]
# Out:
#                                region  gdp_per_capita  population  \
# country_name
# Macao SAR, China  East Asia & Pacific     74017.18471      612167
#
#                   co2_emission  area       density
# country_name
# Macao SAR, China       1283.45  30.3  20203.531353

# %%
df.loc[[df[df.region == 'Europe & Central Asia'].density.idxmax()]]
# Out:
#                              region  gdp_per_capita  population  \
# country_name
# Monaco        Europe & Central Asia    13445.593416       38499
#
#                co2_emission  area  density
# country_name
# Monaco        165114.116337   2.0  19249.5

# %%
df['gdp'] = df.population * df.gdp_per_capita
df
# Out:
#                                            region  gdp_per_capita  population  \
# country_name
# Afghanistan                            South Asia      561.778746    34656032
# Albania                     Europe & Central Asia     4124.982390     2876101
# Algeria                Middle East & North Africa     3916.881571    40606052
# American Samoa                East Asia & Pacific    11834.745230       55599
# Andorra                     Europe & Central Asia    36988.622030       77281
# ...                                           ...             ...         ...
# Virgin Islands (U.S.)   Latin America & Caribbean    13445.593416      102951
# West Bank and Gaza     Middle East & North Africa     2943.404534     4551566
# Yemen, Rep.            Middle East & North Africa      990.334774    27584213
# Zambia                         Sub-Saharan Africa     1269.573537    16591390
# Zimbabwe                       Sub-Saharan Africa     1029.076649    16150362
#
#                         co2_emission       area     density           gdp
# country_name
# Afghanistan              9809.225000   652860.0   53.083405  1.946902e+10
# Albania                  5716.853000    28750.0  100.038296  1.186387e+10
# Algeria                145400.217000  2381740.0   17.048902  1.590491e+11
# American Samoa         165114.116337      200.0  277.995000  6.580000e+08
# Andorra                   462.042000      470.0  164.427660  2.858518e+09
# ...                              ...        ...         ...           ...
# Virgin Islands (U.S.)  165114.116337      350.0  294.145714  1.384237e+09
# West Bank and Gaza     165114.116337     6020.0  756.074086  1.339710e+10
# Yemen, Rep.             22698.730000   527970.0   52.245796  2.731761e+10
# Zambia                   4503.076000   752610.0   22.045136  2.106399e+10
# Zimbabwe                12020.426000   390760.0   41.330643  1.661996e+10
#
# [217 rows x 7 columns]

# %%
gdp_group = df.groupby('region').gdp.aggregate(['mean', 'median'])
gdp_group
# Out:
#                                     mean        median
# region
# East Asia & Pacific         6.013644e+11  1.140065e+10
# Europe & Central Asia       3.490917e+11  4.905225e+10
# Latin America & Caribbean   1.286474e+11  1.364388e+10
# Middle East & North Africa  1.612492e+11  1.020478e+11
# North America               6.718678e+12  1.530681e+12
# South Asia                  3.617451e+11  5.201774e+10
# Sub-Saharan Africa          5.004497e+10  1.098137e+10

# %%
gdp_group['difference'] = (gdp_group['mean'] - gdp_group['median']).abs()
gdp_group
# Out:
#                                     mean        median    difference
# region
# East Asia & Pacific         6.013644e+11  1.140065e+10  5.899637e+11
# Europe & Central Asia       3.490917e+11  4.905225e+10  3.000395e+11
# Latin America & Caribbean   1.286474e+11  1.364388e+10  1.150036e+11
# Middle East & North Africa  1.612492e+11  1.020478e+11  5.920142e+10
# North America               6.718678e+12  1.530681e+12  5.187997e+12
# South Asia                  3.617451e+11  5.201774e+10  3.097274e+11
# Sub-Saharan Africa          5.004497e+10  1.098137e+10  3.906360e+10

# %%
gdp_group[gdp_group['mean'] == gdp_group['median']]
# Out:
# Empty DataFrame
# Columns: [mean, median, difference]
# Index: []

# %%
gdp_group.loc[[gdp_group['difference'].idxmin()]]
# Out:
#                             mean        median    difference
# region
# Sub-Saharan Africa  5.004497e+10  1.098137e+10  3.906360e+10

# %%
df['co2_emission_per_capita'] = df.co2_emission / df.population
df
# Out:
#                                            region  gdp_per_capita  population  \
# country_name
# Afghanistan                            South Asia      561.778746    34656032
# Albania                     Europe & Central Asia     4124.982390     2876101
# Algeria                Middle East & North Africa     3916.881571    40606052
# American Samoa                East Asia & Pacific    11834.745230       55599
# Andorra                     Europe & Central Asia    36988.622030       77281
# ...                                           ...             ...         ...
# Virgin Islands (U.S.)   Latin America & Caribbean    13445.593416      102951
# West Bank and Gaza     Middle East & North Africa     2943.404534     4551566
# Yemen, Rep.            Middle East & North Africa      990.334774    27584213
# Zambia                         Sub-Saharan Africa     1269.573537    16591390
# Zimbabwe                       Sub-Saharan Africa     1029.076649    16150362
#
#                         co2_emission       area     density           gdp  \
# country_name
# Afghanistan              9809.225000   652860.0   53.083405  1.946902e+10
# Albania                  5716.853000    28750.0  100.038296  1.186387e+10
# Algeria                145400.217000  2381740.0   17.048902  1.590491e+11
# American Samoa         165114.116337      200.0  277.995000  6.580000e+08
# Andorra                   462.042000      470.0  164.427660  2.858518e+09
# ...                              ...        ...         ...           ...
# Virgin Islands (U.S.)  165114.116337      350.0  294.145714  1.384237e+09
# West Bank and Gaza     165114.116337     6020.0  756.074086  1.339710e+10
# Yemen, Rep.             22698.730000   527970.0   52.245796  2.731761e+10
# Zambia                   4503.076000   752610.0   22.045136  2.106399e+10
# Zimbabwe                12020.426000   390760.0   41.330643  1.661996e+10
#
#                        co2_emission_per_capita
# country_name
# Afghanistan                           0.000283
# Albania                               0.001988
# Algeria                               0.003581
# American Samoa                        2.969732
# Andorra                               0.005979
# ...                                        ...
# Virgin Islands (U.S.)                 1.603813
# West Bank and Gaza                    0.036276
# Yemen, Rep.                           0.000823
# Zambia                                0.000271
# Zimbabwe                              0.000744
#
# [217 rows x 8 columns]

# %%
sorted_gpd = df.sort_values(by='gdp', ascending=False)
sorted_gpd
# Out:
#                                  region  gdp_per_capita  population  \
# country_name
# United States             North America    57638.159090   323127513
# China               East Asia & Pacific     8123.180873  1378665000
# Japan               East Asia & Pacific    38900.569310   126994511
# Germany           Europe & Central Asia    42161.319660    82667685
# United Kingdom    Europe & Central Asia    40367.037840    65637239
# ...                                 ...             ...         ...
# Palau               East Asia & Pacific    14428.140260       21503
# Marshall Islands    East Asia & Pacific     3665.207477       53066
# Kiribati            East Asia & Pacific     1587.057869      114395
# Nauru               East Asia & Pacific     7821.298918       13049
# Tuvalu              East Asia & Pacific     3083.615251       11097
#
#                   co2_emission       area     density           gdp  \
# country_name
# United States     5.254279e+06  9831510.0   32.866519  1.862448e+13
# China             1.029193e+07  9562911.0  144.167921  1.119915e+13
# Japan             1.214048e+06   377962.0  335.998092  4.940159e+12
# Germany           7.198834e+05   357380.0  231.315924  3.485379e+12
# United Kingdom    4.198202e+05   243610.0  269.435733  2.649581e+12
# ...                        ...        ...         ...           ...
# Palau             2.603570e+02      460.0   46.745652  3.102483e+08
# Marshall Islands  1.026760e+02      180.0  294.811111  1.944979e+08
# Kiribati          6.233900e+01      810.0  141.228395  1.815515e+08
# Nauru             4.767100e+01       20.0  652.450000  1.020601e+08
# Tuvalu            1.100100e+01       30.0  369.900000  3.421888e+07
#
#                   co2_emission_per_capita
# country_name
# United States                    0.016261
# China                            0.007465
# Japan                            0.009560
# Germany                          0.008708
# United Kingdom                   0.006396
# ...                                   ...
# Palau                            0.012108
# Marshall Islands                 0.001935
# Kiribati                         0.000545
# Nauru                            0.003653
# Tuvalu                           0.000991
#
# [217 rows x 8 columns]

# %%
sorted_gpd.head(5)
# Out:
#                                region  gdp_per_capita  population  \
# country_name
# United States           North America    57638.159090   323127513
# China             East Asia & Pacific     8123.180873  1378665000
# Japan             East Asia & Pacific    38900.569310   126994511
# Germany         Europe & Central Asia    42161.319660    82667685
# United Kingdom  Europe & Central Asia    40367.037840    65637239
#
#                 co2_emission       area     density           gdp  \
# country_name
# United States   5.254279e+06  9831510.0   32.866519  1.862448e+13
# China           1.029193e+07  9562911.0  144.167921  1.119915e+13
# Japan           1.214048e+06   377962.0  335.998092  4.940159e+12
# Germany         7.198834e+05   357380.0  231.315924  3.485379e+12
# United Kingdom  4.198202e+05   243610.0  269.435733  2.649581e+12
#
#                 co2_emission_per_capita
# country_name
# United States                  0.016261
# China                          0.007465
# Japan                          0.009560
# Germany                        0.008708
# United Kingdom                 0.006396

# %%
sorted_gpd.tail(5).sort_values(by='gdp')
# Out:
#                                region  gdp_per_capita  population  \
# country_name
# Tuvalu            East Asia & Pacific     3083.615251       11097
# Nauru             East Asia & Pacific     7821.298918       13049
# Kiribati          East Asia & Pacific     1587.057869      114395
# Marshall Islands  East Asia & Pacific     3665.207477       53066
# Palau             East Asia & Pacific    14428.140260       21503
#
#                   co2_emission   area     density           gdp  \
# country_name
# Tuvalu                  11.001   30.0  369.900000  3.421888e+07
# Nauru                   47.671   20.0  652.450000  1.020601e+08
# Kiribati                62.339  810.0  141.228395  1.815515e+08
# Marshall Islands       102.676  180.0  294.811111  1.944979e+08
# Palau                  260.357  460.0   46.745652  3.102483e+08
#
#                   co2_emission_per_capita
# country_name
# Tuvalu                           0.000991
# Nauru                            0.003653
# Kiribati                         0.000545
# Marshall Islands                 0.001935
# Palau                            0.012108

# %%
sorted_co2 = df.sort_values(by='co2_emission_per_capita', ascending=False)
sorted_co2
# Out:
#                                              region  gdp_per_capita  \
# country_name
# St. Martin (French part)  Latin America & Caribbean    13445.593416
# San Marino                    Europe & Central Asia    47908.561410
# Monaco                        Europe & Central Asia    13445.593416
# Northern Mariana Islands        East Asia & Pacific    22572.378820
# American Samoa                  East Asia & Pacific    11834.745230
# ...                                             ...             ...
# Congo, Dem. Rep.                 Sub-Saharan Africa      405.542501
# Chad                             Sub-Saharan Africa      664.295652
# Somalia                          Sub-Saharan Africa      434.208810
# Burundi                          Sub-Saharan Africa      285.727442
# Eritrea                          Sub-Saharan Africa    13445.593416
#
#                           population   co2_emission       area       density  \
# country_name
# St. Martin (French part)       31949  165114.116337       54.4    587.297794
# San Marino                     33203  165114.116337       60.0    553.383333
# Monaco                         38499  165114.116337        2.0  19249.500000
# Northern Mariana Islands       55023  165114.116337      460.0    119.615217
# American Samoa                 55599  165114.116337      200.0    277.995000
# ...                              ...            ...        ...           ...
# Congo, Dem. Rep.            78736153    4671.758000  2344860.0     33.578189
# Chad                        14452543     729.733000  1284000.0     11.255875
# Somalia                     14317996     608.722000   637660.0     22.453966
# Burundi                     10524117     440.040000    27830.0    378.157276
# Eritrea                     34322559     696.730000   117600.0    291.858495
#
#                                    gdp  co2_emission_per_capita
# country_name
# St. Martin (French part)  4.295733e+08                 5.168053
# San Marino                1.590708e+09                 4.972867
# Monaco                    5.176419e+08                 4.288790
# Northern Mariana Islands  1.242000e+09                 3.000820
# American Samoa            6.580000e+08                 2.969732
# ...                                ...                      ...
# Congo, Dem. Rep.          3.193086e+10                 0.000059
# Chad                      9.600761e+09                 0.000050
# Somalia                   6.217000e+09                 0.000043
# Burundi                   3.007029e+09                 0.000042
# Eritrea                   4.614872e+11                 0.000020
#
# [217 rows x 8 columns]

# %%
sorted_co2.head(5)
# Out:
#                                              region  gdp_per_capita  \
# country_name
# St. Martin (French part)  Latin America & Caribbean    13445.593416
# San Marino                    Europe & Central Asia    47908.561410
# Monaco                        Europe & Central Asia    13445.593416
# Northern Mariana Islands        East Asia & Pacific    22572.378820
# American Samoa                  East Asia & Pacific    11834.745230
#
#                           population   co2_emission   area       density  \
# country_name
# St. Martin (French part)       31949  165114.116337   54.4    587.297794
# San Marino                     33203  165114.116337   60.0    553.383333
# Monaco                         38499  165114.116337    2.0  19249.500000
# Northern Mariana Islands       55023  165114.116337  460.0    119.615217
# American Samoa                 55599  165114.116337  200.0    277.995000
#
#                                    gdp  co2_emission_per_capita
# country_name
# St. Martin (French part)  4.295733e+08                 5.168053
# San Marino                1.590708e+09                 4.972867
# Monaco                    5.176419e+08                 4.288790
# Northern Mariana Islands  1.242000e+09                 3.000820
# American Samoa            6.580000e+08                 2.969732

# %%
sorted_co2.tail(5).sort_values(by='co2_emission_per_capita')
# Out:
#                               region  gdp_per_capita  population  \
# country_name
# Eritrea           Sub-Saharan Africa    13445.593416    34322559
# Burundi           Sub-Saharan Africa      285.727442    10524117
# Somalia           Sub-Saharan Africa      434.208810    14317996
# Chad              Sub-Saharan Africa      664.295652    14452543
# Congo, Dem. Rep.  Sub-Saharan Africa      405.542501    78736153
#
#                   co2_emission       area     density           gdp  \
# country_name
# Eritrea                696.730   117600.0  291.858495  4.614872e+11
# Burundi                440.040    27830.0  378.157276  3.007029e+09
# Somalia                608.722   637660.0   22.453966  6.217000e+09
# Chad                   729.733  1284000.0   11.255875  9.600761e+09
# Congo, Dem. Rep.      4671.758  2344860.0   33.578189  3.193086e+10
#
#                   co2_emission_per_capita
# country_name
# Eritrea                          0.000020
# Burundi                          0.000042
# Somalia                          0.000043
# Chad                             0.000050
# Congo, Dem. Rep.                 0.000059
